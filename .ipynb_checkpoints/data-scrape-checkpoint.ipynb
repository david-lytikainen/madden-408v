# %%
import pandas as pd
import numpy as np
import requests
import re

# %%
data = pd.read_csv("nfl_2021_stats.csv")

# %%
data
# Out:
#     Unnamed: 0          Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Games
# 0           Rk              Player         Tm        Age        Pos     G  \
# 1            1   Jonathan Taylor*+        IND         22         RB    17
# 2            2       Cooper Kupp*+        LAR         28         WR    17
# 3            3      Deebo Samuel*+        SFO         25         WR    16
# 4            4       Najee Harris*        PIT         23         RB    17
# ..         ...                 ...        ...        ...        ...   ...
# 495        495    Garrett Bradbury        MIN         26          C    13
# 496        496      Jesper Horsted        CHI         24         WR     7
# 497        497       Patrick Laird        MIA         26         RB     6
# 498        498  Gardner Minshew II        PHI         25         QB     4
# 499        499       Dezmon Patmon        IND         23         WR     8
#
#     Unnamed: 6 Receiving Unnamed: 8 Unnamed: 9  ... Unnamed: 21 Unnamed: 22
# ...
